# %% [markdown]
# # File for dataset preparation

# %%
import sqlite3
import pandas as pd

# %% [markdown]
# ## 1. SQL data retrieval

# %%
conn = sqlite3.connect('cagey.db') 

cursor = conn.cursor() 

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:", tables)

conn.close()
# Out:
# Tables in the database: [('precursors',), ('reactions',), ('nmr_spectra',), ('nmr_aldehyde_peaks',), ('nmr_imine_peaks',), ('mass_spectra',), ('mass_spectrum_peaks',), ('mass_spectrum_topology_assignments',), ('turbidity_dissolved_references',), ('turbidity_measurements',), ('turbidities',)]

# %%
conn = sqlite3.connect('cagey.db')

tables_query = "SELECT name FROM sqlite_master WHERE type='table';"
tables_df = pd.read_sql(tables_query, conn)
table_names = tables_df['name'].tolist()  

tables_dataframes = {}

for table in table_names:
    query = f"SELECT * FROM {table}"  
    df = pd.read_sql(query, conn)    
    tables_dataframes[table] = df     
    print(f"Table {table} loaded successfully with {len(df)} rows.")

conn.close()
# Out:
# Table precursors loaded successfully with 55 rows.
# Table reactions loaded successfully with 450 rows.
# Table nmr_spectra loaded successfully with 449 rows.
# Table nmr_aldehyde_peaks loaded successfully with 751 rows.
# Table nmr_imine_peaks loaded successfully with 8897 rows.
# Table mass_spectra loaded successfully with 401 rows.
# Table mass_spectrum_peaks loaded successfully with 710 rows.
# Table mass_spectrum_topology_assignments loaded successfully with 541 rows.
# Table turbidity_dissolved_references loaded successfully with 402 rows.
# Table turbidity_measurements loaded successfully with 6824 rows.
# Table turbidities loaded successfully with 402 rows.

# %%
for table_name, df in tables_dataframes.items():
    print(f"Table: {table_name}, Type: {type(df)}")
    print(f"First value in first row: {df.iloc[0, 0]}, Type: {type(df.iloc[0, 0])}")
# Out:
# Table: precursors, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: Di1, Type: <class 'str'>
# Table: reactions, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: nmr_spectra, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: nmr_aldehyde_peaks, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: nmr_imine_peaks, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: mass_spectra, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: mass_spectrum_peaks, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: mass_spectrum_topology_assignments, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: turbidity_dissolved_references, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: turbidity_measurements, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>
# Table: turbidities, Type: <class 'pandas.core.frame.DataFrame'>
# First value in first row: 1, Type: <class 'numpy.int64'>

# %%
tables_dataframes['precursors']
# Out:
#     name                                             smiles
# 0    Di1                                   O=Cc1cccc(C=O)c1
# 1    Di2                      CC(C)(C)c1cc(C=O)c(O)c(C=O)c1
# 2    Di3                               O=Cc1cc2sc(C=O)cc2s1
# 3    Di4                                   O=Cc1ccc(C=O)cc1
# 4    Di5                         O=Cc1c(F)c(F)c(C=O)c(F)c1F
# 5    Di6                        O=Cc1ccc(-c2ccc(C=O)cc2)cc1
# 6    Di7                       O=Cc1c2ccccc2c(C=O)c2ccccc12
# 7    Di8                       O=Cc1ccc2ccc3ccc(C=O)nc3c2n1
# 8    Di9                                      O=Cc1ccsc1C=O
# 9   Di10                                     O=Cc1ccccc1C=O
# 10  Di11                        Cn1nc(-c2ccc(C=O)cc2)cc1C=O
# 11  Di12                       CC(C=O)=Cc1ccc(C=C(C)C=O)cc1
# 12  Di13                 COc1cc(C=O)ccc1OCCOc1ccc(C=O)cc1OC
# 13  Di14                             Cn1nc2c(C=O)cccc2c1C=O
# 14  Di15                    O=Cc1ccc(OCCCOc2ccc(C=O)cc2)cc1
# 15  Di16                    CCCCC(CC)COc1cc(C=O)c(OC)cc1C=O
# 16  Di17                                               NCCN
# 17  Di18                                        CC(C)(CN)CN
# 18  Di19                      N[C@H]1CN(Cc2ccccc2)C[C@@H]1N
# 19  Di20             N[C@H]([C@H](C1=CC=CC=C1)N)C2=CC=CC=C2
# 20  Di21                            Nc1ccc(Oc2ccc(N)cc2)cc1
# 21  Di22                                        NC1=NON=C1N
# 22  Di23                               N[C@H]1CCC[C@H](C1)N
# 23  Di24                              N[C@@H]1[C@H](CCCC1)N
# 24  Di25                                    NCCCCCCNCCCCCCN
# 25  Di26                                           NCCCCCCN
# 26  Di27                                     NCc1ccc(CN)cc1
# 27  Di28                                     NCC1CCC(CN)CC1
# 28  Di29                                       CN(CCCN)CCCN
# 29  Di30                                            NCCOCCN
# 30  Di31                                  NCC1=CC(CN)=CC=C1
# 31  Di32                                           NCC(CN)O
# 32  Di33                                NCCCC[C@H](N)C(=O)O
# 33  Di34                               N[C@H]1CC[C@H](N)CC1
# 34  TriA                                    Nc1nc(N)nc(N)n1
# 35  TriB                          Cc1c(CN)c(C)c(CN)c(C)c1CN
# 36  TriC                                       NCCN(CCN)CCN
# 37  TriD                       CCc1c(CN)c(CC)c(CN)c(CC)c1CN
# 38  TriE                                    NCCCN(CCCN)CCCN
# 39  TriF                                    NC1CC(N)CC(N)C1
# 40  TriG                              O=Cc1cc(C=O)cc(C=O)c1
# 41  TriH  O=Cc1ccc(-c2cc(-c3ccc(C=O)cc3)cc(-c3ccc(C=O)cc...
# 42  TriI                           O=Cc1cc(C=O)c(O)c(C=O)c1
# 43  TriJ         O=Cc1ccc(N(c2ccc(C=O)cc2)c2ccc(C=O)cc2)cc1
# 44  TriK  O=Cc1ccc(-c2nc(-c3ccc(C=O)cc3)nc(-c3ccc(C=O)cc...
# 45  TriL  O=Cc1ccc(C#Cc2cc(C#Cc3ccc(C=O)cc3)cc(C#Cc3ccc(...
# 46  TriM  O=Cc1cccc(-c2cc(-c3cccc(C=O)c3)cc(-c3cccc(C=O)...
# 47  TriN   O=Cc1ccccc1-c1cc(-c2ccccc2C=O)cc(-c2ccccc2C=O)c1
# 48  TriO  O=Cc1cc(-c2cc(-c3csc(C=O)c3)cc(-c3csc(C=O)c3)c...
# 49  TriP  O=Cc1ccc(-c2cc(-c3ccc(C=O)o3)cc(-c3ccc(C=O)o3)...
# 50  TriQ  O=CC=Cc1ccc(-c2cc(-c3ccc(C=CC=O)cc3)cc(-c3ccc(...
# 51  TriR  O=Cc1ccc(OCc2cc(COc3ccc(C=O)cc3)cc(COc3ccc(C=O...
# 52  TriS                 O=Cc1ccc(C#Cc2cc(C=O)cc(C=O)c2)cc1
# 53  TriT                       O=Cc1c(O)c(C=O)c(O)c(C=O)c1O
# 54  TriU  O=Cc1ccc(C=Cc2cc(C=Cc3ccc(C=O)cc3)cc(C=Cc3ccc(...

# %% [markdown]
# # Threshold arounf 55% in turbidity

# %% [markdown]
# ## 1.1. Building few-shot examples and test set

# %%
building_blocks_pairs = pd.DataFrame()
building_blocks_pairs[['experiment_number', 'di_name', 'tri_name']] = tables_dataframes['reactions'][['experiment', 'di_name', 'tri_name']]

building_blocks_pairs['di_smiles'] = ""
building_blocks_pairs['tri_smiles'] = ""


for index, row in building_blocks_pairs.iterrows():

    di_name = row['di_name']
    tri_name = row['tri_name']
    
    di_smiles_row = tables_dataframes['precursors'][tables_dataframes['precursors']['name'] == di_name]
    if not di_smiles_row.empty:
        building_blocks_pairs.at[index, 'di_smiles'] = di_smiles_row['smiles'].values[0]  
    
    tri_smiles_row = tables_dataframes['precursors'][tables_dataframes['precursors']['name'] == tri_name]
    if not tri_smiles_row.empty:
        building_blocks_pairs.at[index, 'tri_smiles'] = tri_smiles_row['smiles'].values[0]

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # *** NEW PREP DATA ***

# %%
import json

file_path = '/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/precursor_combination_map_to_exp_data.json'  

with open(file_path, 'r') as file:
    json_data = json.load(file)

count = len(json_data)

print(f"Number of instances in the JSON: {count}")
# Out:
# Number of instances in the JSON: 366

# %%
import os

# %%
import json
import pandas as pd
import os

file_path = '/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/precursor_combination_map_to_exp_data.json'  # Replace with your JSON file path

with open(file_path, 'r') as file:
    json_data = json.load(file)

base_dir = '/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm'

rows = []

for key, value in json_data.items():
    precursor_combination = value['precursor_combination']
    plate_number = value['plate_number']
    turbidity_data_path = value['turbidity_data_path']
    full_turbidity_path = os.path.join(base_dir, turbidity_data_path.lstrip('/'), 'turbidity_data.csv')

    print(f"[{precursor_combination}] Trying to access file: {full_turbidity_path}")

    if os.path.exists(full_turbidity_path):
        try:
            turbidity_df = pd.read_csv(full_turbidity_path)

            print(f"[{precursor_combination}] Original Columns in {full_turbidity_path}: {turbidity_df.columns}")

            turbidity_df.columns = turbidity_df.columns.str.strip().str.lower()

            print(f"[{precursor_combination}] Normalized Columns in {full_turbidity_path}: {turbidity_df.columns}")

            if 'turbidity' in turbidity_df.columns:
                mean_turbidity = turbidity_df['turbidity'].mean()
                print(f"[{precursor_combination}] Mean turbidity found: {mean_turbidity}")
            else:
                print(f"[{precursor_combination}] 'turbidity' column not found in: {full_turbidity_path}")
                mean_turbidity = None
        except Exception as e:

            print(f"[{precursor_combination}] Error reading file {full_turbidity_path}: {e}")
            mean_turbidity = None
    else:
        print(f"[{precursor_combination}] File does not exist: {full_turbidity_path}")
        mean_turbidity = None

    rows.append({'precursor_combination': precursor_combination, 'plate_number': plate_number, 'turbidity': mean_turbidity})

turbidity_df = pd.DataFrame(rows)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(turbidity_df)

turbidity_df.to_csv('mean_turbidity_data.csv', index=False)
# Out:
# [A1] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv
# [A1] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A1] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A1] Mean turbidity found: 89.3897306681133
# [A2] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv
# [A2] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A2] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A2] Mean turbidity found: 95.42376421663637
# [A3] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv
# [A3] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A3] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A3] Mean turbidity found: 85.60818769955888
# [A4] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv
# [A4] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A4] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A4] Mean turbidity found: 100.88581352165048
# [A5] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv
# [A5] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A5] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A5] Mean turbidity found: 104.25999195318843
# [A6] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_6/turbidity_data.csv
# [A6] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_6/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A6] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_6/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A6] Mean turbidity found: 74.23966381233599
# [A7] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_7/turbidity_data.csv
# [A7] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_7/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A7] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_7/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A7] Mean turbidity found: 79.8638621489279
# [A8] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_8/turbidity_data.csv
# [A8] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_8/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A8] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_8/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A8] Mean turbidity found: 103.7091003631233
# [A9] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_1/turbidity_data.csv
# [A9] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_1/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A9] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_1/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A9] Mean turbidity found: 70.60357590820898
# [A10] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_2/turbidity_data.csv
# [A10] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_2/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A10] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_2/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A10] Mean turbidity found: 104.6873321948999
# [A11] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_3/turbidity_data.csv
# [A11] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_3/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A11] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_3/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A11] Mean turbidity found: 76.9927593222902
# [A12] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_4/turbidity_data.csv
# [A12] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_4/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A12] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_4/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A12] Mean turbidity found: 100.92468962217103
# [A13] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_5/turbidity_data.csv
# [A13] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_5/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A13] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_5/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A13] Mean turbidity found: 78.25828313090247
# [A14] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_6/turbidity_data.csv
# [A14] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_6/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A14] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_6/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A14] Mean turbidity found: 75.35453300111156
# [A15] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_7/turbidity_data.csv
# [A15] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_7/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A15] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_7/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A15] Mean turbidity found: 77.93548433237005
# [A16] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_8/turbidity_data.csv
# [A16] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_8/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A16] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_8/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A16] Mean turbidity found: 73.44841115341325
# [B1] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_9/turbidity_data.csv
# [B1] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_9/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [B1] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_9/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [B1] Mean turbidity found: 68.01041899779516
# [B2] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_10/turbidity_data.csv
# [B2] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_10/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [B2] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_10/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [B2] Mean turbidity found: 51.066493744658274
# [B3] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_11/turbidity_data.csv
# [B3] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_11/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [B3] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_11/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [B3] Mean turbidity found: 108.90159856636721
# [B4] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_12/turbidity_data.csv
# [B4] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_12/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [B4] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_12/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [B4] Mean turbidity found: 57.66172808160697
# [B5] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study
# 165                   J32           04   24.853109
# 166                   J33           04   24.357120
# 167                   J34           04   23.730365
# 168                   K17           02   87.091188
# 169                   K18           02   73.820049
# 170                   K19           02   86.656875
# 171                   K20           02   58.445986
# 172                   K21           02   78.861062
# 173                   K22           02   67.128912
# 174                   K23           02   69.750460
# 175                   K24           02   70.446546
# 176                   K25           01   34.360000
# 177                   K26           01   26.666186
# 178                   K27           04   55.294637
# 179                   K28           04   70.743767
# 180                   K29           04   23.692474
# 181                   K30           04   25.929304
# 182                   K31           04   30.457220
# 183                   K32           04   34.291466
# 184                   K33           04   22.379683
# 185                   K34           04   49.934758
# 186                   L17           02   78.393225
# 187                   L18           02   78.819791
# 188                   L19           02   88.278424
# 189                   L20           02   70.350973
# 190                   L21           02   74.535182
# 191                   L22           02   73.441668
# 192                   L23           02   84.758135
# 193                   L24           02   76.390771
# 194                   L25           01         NaN
# 195                   L26           01         NaN
# 196                   L27           01         NaN
# 197                   L28           01         NaN
# 198                   L29           01         NaN
# 199                   L30           01         NaN
# 200                   L31           01         NaN
# 201                   L32           01         NaN
# 202                   L33           02         NaN
# 203                   L34           02         NaN
# 204                   M17           04         NaN
# 205                   M18           04         NaN
# 206                   M19           04         NaN
# 207                   M20           04         NaN
# 208                   M21           04         NaN
# 209                   M22           04         NaN
# 210                   M23           04         NaN
# 211                   M24           04         NaN
# 212                   M25           01         NaN
# 213                   M26           01   29.940533
# 214                   M27           01   30.161885
# 215                   M28           01   34.518478
# 216                   M29           01   30.939653
# 217                   M30           01   28.892638
# 218                   M31           01   46.496463
# 219                   M32           01   40.643063
# 220                   M33           02         NaN
# 221                   M34           02   36.267435
# 222                   N17           04         NaN
# 223                   N18           04         NaN
# 224                   N19           04         NaN
# 225                   N20           04         NaN
# 226                   N21           04         NaN
# 227                   N22           04         NaN
# 228                   N23           04         NaN
# 229                   N24           04         NaN
# 230                   N25           01   33.504501
# 231                   N26           01   27.922453
# 232                   N27           01   36.045314
# 233                   N28           01   30.195806
# 234                   N29           01   31.952765
# 235                   N30           01   30.566497
# 236                   N31           01   35.912275
# 237                   N32           01   30.761978
# 238                   N33           02   24.150737
# 239                   N34           02   23.108107
# 240                   O17           04         NaN
# 241                   O18           04         NaN
# 242                   O19           04         NaN
# 243                   O20           04         NaN
# 244                   O21           04         NaN
# 245                   O22           04         NaN
# 246                   O23           04         NaN
# 247                   O24           04         NaN
# 248                   O25           01   27.196924
# 249                   O26           01   52.907370
# 250                   O27           01   54.936631
# 251                   O28           01   46.433537
# 252                   O29           01   32.544462
# 253                   O30           01   38.150390
# 254                   O31           01   42.831073
# 255                   O32           01   60.997084
# 256                   O33           02   26.646382
# 257                   O34           02   32.210914
# 258                   P17           04         NaN
# 259                   P18           04         NaN
# 260                   P19           04         NaN
# 261                   P20           04         NaN
# 262                   P21           04         NaN
# 263                   P22           04         NaN
# 264                   P23           04         NaN
# 265                   P24           04         NaN
# 266                   P25           01   37.775486
# 267                   P26           01   42.062661
# 268                   P27           01   50.374040
# 269                   P28           01   46.257788
# 270                   P29           01   34.086741
# 271                   P30           01   39.700055
# 272                   P31           01   47.707575
# 273                   P32           01   75.900301
# 274                   P33           02   22.937723
# 275                   P34           02   35.810402
# 276                   Q17           04         NaN
# 277                   Q18           04         NaN
# 278                   Q19           04         NaN
# 279                   Q20           04         NaN
# 280                   Q21           04         NaN
# 281                   Q22           04         NaN
# 282                   Q23           04         NaN
# 283                   Q24           04         NaN
# 284                   Q25           01   37.877305
# 285                   Q26           01   50.750772
# 286                   Q27           01   65.661179
# 287                   Q28           01   42.627636
# 288                   Q29           01   27.448617
# 289                   Q30           01   42.775255
# 290                   Q31           01   54.160972
# 291                   Q32           01   83.382494
# 292                   Q33           02   29.985468
# 293                   Q34           02   55.261265
# 294                   R17           04         NaN
# 295                   R18           04         NaN
# 296                   R19           04         NaN
# 297                   R20           04         NaN
# 298                   R21           04         NaN
# 299                   R22           04         NaN
# 300                   R23           04         NaN
# 301                   R24           04         NaN
# 302                   R25           01   29.392684
# 303                   R26           01   26.071873
# 304                   R27           04   22.634869
# 305                   R28           04   22.026089
# 306                   R29           04   21.683211
# 307                   R30           04   22.099050
# 308                   R31           04   22.184545
# 309                   R29           04   22.401117
# 310                   R30           04   20.816427
# 311                   R31           04   22.202784
# 312                   S17           02   30.891416
# 313                   S18           03   24.345263
# 314                   S19           03   43.844084
# 315                   S20           03   30.904790
# 316                   S21           02   32.053687
# 317                   S22           03   26.845735
# 318                   S23           03   33.226259
# 319                   S24           03   24.804133
# 320                   S25           03         NaN
# 321                   S26           03   27.085720
# 322                   S27           03   40.322795
# 323                   S28           03   37.145523
# 324                   S29           03   30.381202
# 325                   S30           03   30.079458
# 326                   S31           03   39.056735
# 327                   S32           03   32.298292
# 328                   S33           03   24.593158
# 329                   S34           03   40.126493
# 330                   T17           02   75.356799
# 331                   T18           03   33.859855
# 332                   T19           03   42.699069
# 333                   T20           03   26.082787
# 334                   T21           02   50.237403
# 335                   T22           03   27.391257
# 336                   T23           03   49.893172
# 337                   T24           03   26.819446
# 338                   T25           03   47.569127
# 339                   T26           03   66.633797
# 340                   T27           03   78.768046
# 341                   T28           03   60.867133
# 342                   T29           03   36.095824
# 343                   T30           03   55.739782
# 344                   T31           03   60.172959
# 345                   T32           03   54.769259
# 346                   T33           03   21.277391
# 347                   T34           03   48.064622
# 348                   U17           02   39.283404
# 349                   U18           03   30.474355
# 350                   U19           03   58.274367
# 351                   U20           03   85.305632
# 352                   U21           02         NaN
# 353                   U22           03   99.155323
# 354                   U23           03   59.660607
# 355                   U24           03   48.012253
# 356                   U25           03   28.470370
# 357                   U26           03   41.759807
# 358                   U27           03   59.691834
# 359                   U28           03   61.257752
# 360                   U29           03   24.345896
# 361                   U30           03   42.532789
# 362                   U31           03   30.918623
# 363                   U32           03   47.558380
# 364                   U33           03   28.706079
# 365                   U34           03   50.140653

# %%
import json
import pandas as pd
import os

file_path = '/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/precursor_combination_map_to_exp_data.json'  # Replace with your JSON file path

with open(file_path, 'r') as file:
    json_data = json.load(file)

base_dir = '/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm'

rows = []

for key, value in json_data.items():
    precursor_combination = value['precursor_combination']
    plate_number = value['plate_number']
    turbidity_data_path = value['turbidity_data_path']
    full_turbidity_path = os.path.join(base_dir, turbidity_data_path.lstrip('/'), 'turbidity_data.csv')

    print(f"[{precursor_combination}] Trying to access file: {full_turbidity_path}")

    if os.path.exists(full_turbidity_path):
        try:
            turbidity_df = pd.read_csv(full_turbidity_path)

            print(f"[{precursor_combination}] Original Columns in {full_turbidity_path}: {turbidity_df.columns}")

            turbidity_df.columns = turbidity_df.columns.str.strip().str.lower()

            print(f"[{precursor_combination}] Normalized Columns in {full_turbidity_path}: {turbidity_df.columns}")

            if 'turbidity' in turbidity_df.columns:
                mean_turbidity = turbidity_df['turbidity'].mean()
                print(f"[{precursor_combination}] Mean turbidity found: {mean_turbidity}")
            else:
                print(f"[{precursor_combination}] 'turbidity' column not found in: {full_turbidity_path}")
                mean_turbidity = None
        except Exception as e:
            print(f"[{precursor_combination}] Error reading file {full_turbidity_path}: {e}")
            mean_turbidity = None
    else:
        modified_turbidity_data_path = turbidity_data_path.rstrip('0123456789') + '0' + turbidity_data_path[-1]
        full_modified_turbidity_path = os.path.join(base_dir, modified_turbidity_data_path.lstrip('/'), 'turbidity_data.csv')
        print(f"[{precursor_combination}] Trying to access modified file path: {full_modified_turbidity_path}")

        if os.path.exists(full_modified_turbidity_path):
            try:
                turbidity_df = pd.read_csv(full_modified_turbidity_path)

                print(f"[{precursor_combination}] Original Columns in {full_modified_turbidity_path}: {turbidity_df.columns}")

                turbidity_df.columns = turbidity_df.columns.str.strip().str.lower()

                print(f"[{precursor_combination}] Normalized Columns in {full_modified_turbidity_path}: {turbidity_df.columns}")

                if 'turbidity' in turbidity_df.columns:
                    mean_turbidity = turbidity_df['turbidity'].mean()
                    print(f"[{precursor_combination}] Mean turbidity found: {mean_turbidity}")
                else:
                    print(f"[{precursor_combination}] 'turbidity' column not found in: {full_modified_turbidity_path}")
                    mean_turbidity = None
            except Exception as e:
                print(f"[{precursor_combination}] Error reading file {full_modified_turbidity_path}: {e}")
                mean_turbidity = None
        else:
            print(f"[{precursor_combination}] File does not exist: {full_turbidity_path} or {full_modified_turbidity_path}")
            mean_turbidity = None

    rows.append({'precursor_combination': precursor_combination, 'plate_number': plate_number, 'turbidity': mean_turbidity})

turbidity_df = pd.DataFrame(rows)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

print(turbidity_df)

turbidity_df.to_csv('mean_turbidity_data.csv', index=False)
# Out:
# [A1] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv
# [A1] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A1] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_1/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A1] Mean turbidity found: 89.3897306681133
# [A2] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv
# [A2] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A2] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_2/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A2] Mean turbidity found: 95.42376421663637
# [A3] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv
# [A3] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A3] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_3/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A3] Mean turbidity found: 85.60818769955888
# [A4] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv
# [A4] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A4] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_4/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A4] Mean turbidity found: 100.88581352165048
# [A5] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv
# [A5] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [A5] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_5/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [A5] Mean turbidity found: 104.25999195318843
# [A6] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study
Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_26/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D10] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_26/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D10] Mean turbidity found: 55.890270586288665
# [D11] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_27/turbidity_data.csv
# [D11] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_27/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D11] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_27/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D11] Mean turbidity found: 52.37679952076338
# [D12] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_28/turbidity_data.csv
# [D12] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_28/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D12] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_28/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D12] Mean turbidity found: 59.7539592621388
# [D13] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_29/turbidity_data.csv
# [D13] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_29/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D13] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_29/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D13] Mean turbidity found: 54.454254548774344
# [D14] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_30/turbidity_data.csv
# [D14] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_30/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D14] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_30/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D14] Mean turbidity found: 57.57273341452725
# [D15] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_31/turbidity_data.csv
# [D15] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_31/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D15] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_31/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D15] Mean turbidity found: 55.069114336409676
# [D16] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_32/turbidity_data.csv
# [D16] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_32/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [D16] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/03/solubility_study_32/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [D16] Mean turbidity found: 58.44660422384277
# [E1] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_33/turbidity_data.csv
# [E1] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_33/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E1] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_33/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E1] Mean turbidity found: 77.14365028159386
# [E2] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_34/turbidity_data.csv
# [E2] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_34/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E2] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_34/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E2] Mean turbidity found: 56.025139801766365
# [E3] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_35/turbidity_data.csv
# [E3] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_35/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E3] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_35/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E3] Mean turbidity found: 84.83322601766679
# [E4] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_36/turbidity_data.csv
# [E4] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_36/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E4] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_36/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E4] Mean turbidity found: 56.36883985368441
# [E5] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_37/turbidity_data.csv
# [E5] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_37/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E5] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_37/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E5] Mean turbidity found: 78.57970349028491
# [E6] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_38/turbidity_data.csv
# [E6] Original Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_38/turbidity_data.csv: Index(['Timestamp', 'Time (s)', 'Time (min)', 'Time (hour)', 'Turbidity'], dtype='object')
# [E6] Normalized Columns in /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_38/turbidity_data.csv: Index(['timestamp', 'time (s)', 'time (min)', 'time (hour)', 'turbidity'], dtype='object')
# [E6] Mean turbidity found: 49.85453171838
# [E7] Trying to access file: /Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/turbidity/AB-02-005/01/solubility_study_39/turbidity_data.csv
# ...
# 53                     D6           01   56.476655
# 54                     D7           01   46.903339
# 55                     D8           01   55.673726
# 56                     D9           03   61.862173
# 57                    D10           03   55.890271
# 58                    D11           03   52.376800
# 59                    D12           03   59.753959
# 60                    D13           03   54.454255
# 61                    D14           03   57.572733
# 62                    D15           03   55.069114
# 63                    D16           03   58.446604
# 64                     E1           01   77.143650
# 65                     E2           01   56.025140
# 66                     E3           01   84.833226
# 67                     E4           01   56.368840
# 68                     E5           01   78.579703
# 69                     E6           01   49.854532
# 70                     E7           01   70.651918
# 71                     E8           01   62.120374
# 72                     E9           03   54.734559
# 73                    E10           03   66.122437
# 74                    E11           03   55.393667
# 75                    E12           03   61.337634
# 76                    E13           03   55.552112
# 77                    E14           03   56.112930
# 78                    E15           03   52.826659
# 79                    E16           03   56.151625
# 80                     F1           01   60.899291
# 81                     F2           01   72.156390
# 82                     F3           01  103.496996
# 83                     F4           01   67.760131
# 84                     F5           01   73.076532
# 85                     F6           01   79.296296
# 86                     F7           01   72.581067
# 87                     F8           01   90.656787
# 88                     F9           03   62.821264
# 89                    F10           03   73.652356
# 90                    F11           03   64.080244
# 91                    F12           03   61.186374
# 92                    F13           03   63.817814
# 297                   R20           04   49.726902
# 298                   R21           04   69.217291
# 299                   R22           04   48.630767
# 300                   R23           04   51.324257
# 301                   R24           04   45.267244
# 302                   R25           01   29.392684
# 303                   R26           01   26.071873
# 304                   R27           04   22.634869
# 305                   R28           04   22.026089
# 306                   R29           04   21.683211
# 307                   R30           04   22.099050
# 308                   R31           04   22.184545
# 309                   R32           04   22.401117
# 310                   R33           04   20.816427
# 311                   R34           04   22.202784
# 312                   S17           02   30.891416
# 313                   S18           03   24.345263
# 314                   S19           03   43.844084
# 315                   S20           03   30.904790
# 316                   S21           02   32.053687
# 317                   S22           03   26.845735
# 318                   S23           03   33.226259
# 319                   S24           03   24.804133
# 320                   S25           03         NaN
# 321                   S26           03   27.085720
# 322                   S27           03   40.322795
# 323                   S28           03   37.145523
# 324                   S29           03   30.381202
# 325                   S30           03   30.079458
# 326                   S31           03   39.056735
# 327                   S32           03   32.298292
# 328                   S33           03   24.593158
# 329                   S34           03   40.126493
# 330                   T17           02   75.356799
# 331                   T18           03   33.859855
# 332                   T19           03   42.699069
# 333                   T20           03   26.082787
# 334                   T21           02   50.237403
# 335                   T22           03   27.391257
# 336                   T23           03   49.893172
# 337                   T24           03   26.819446
# 338                   T25           03   47.569127
# 339                   T26           03   66.633797
# 340                   T27           03   78.768046
# 341                   T28           03   60.867133
# 342                   T29           03   36.095824
# 343                   T30           03   55.739782
# 344                   T31           03   60.172959
# 345                   T32           03   54.769259
# 346                   T33           03   21.277391
# 347                   T34           03   48.064622
# 348                   U17           02   39.283404
# 349                   U18           03   30.474355
# 350                   U19           03   58.274367
# 351                   U20           03   85.305632
# 352                   U21           02         NaN
# 353                   U22           03   99.155323
# 354                   U23           03   59.660607
# 355                   U24           03   48.012253
# 356                   U25           03   28.470370
# 357                   U26           03   41.759807
# 358                   U27           03   59.691834
# 359                   U28           03   61.257752
# 360                   U29           03   24.345896
# 361                   U30           03   42.532789
# 362                   U31           03   30.918623
# 363                   U32           03   47.558380
# 364                   U33           03   28.706079
# 365                   U34           03   50.140653

# %%
turbidity_df

# %%
turbidity_df.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_turbidity_data.csv')

# %% [markdown]
# ### Here I mmanually added the remaining ones

# %%
turbitiy_final = pd.read_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_turbidity_data.csv')

# %%
turbitiy_final

# %%
turbitiy_final['turbidity_label'] = turbitiy_final['turbidity'].apply(lambda x: 'turbid' if x >= 55.2 else 'dissolved')

turbitiy_final['turbidity_binary'] = turbitiy_final['turbidity_label'].apply(lambda x: 0 if x == 'turbid' else 1)

turbitiy_final

# %%
label_counts = turbitiy_final['turbidity_label'].value_counts()

label_counts
# Out:
# turbidity_label
# dissolved    193
# turbid       173
# Name: count, dtype: int64

# %%
turbitiy_final.columns
# Out:
# Index(['Unnamed: 0', 'precursor_combination', 'plate_number', 'turbidity',
#        'turbidity_label', 'turbidity_binary'],
#       dtype='object')

# %%
turbitiy_final.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')

# %%
duplicate_rows = turbitiy_final[turbitiy_final.duplicated(subset=['precursor_combination', 'plate_number', 'turbidity', 'turbidity_label'], keep=False)]

print(duplicate_rows)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, precursor_combination, plate_number, turbidity, turbidity_label, turbidity_binary]
# Index: []

# %%
duplicates = turbitiy_final[turbitiy_final.duplicated(subset=['precursor_combination', 'plate_number', 'turbidity'])]
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, precursor_combination, plate_number, turbidity, turbidity_label, turbidity_binary]
# Index: []

# %%
turbidity_final = pd.read_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')

# %%
turbidity_final['tri_code'] = turbidity_final['precursor_combination'].str[0]  
turbidity_final['di_code'] = turbidity_final['precursor_combination'].str[1:].astype(int)  

tri_mapping = {chr(65 + i): f'Tri{chr(65 + i)}' for i in range(21)}  
di_mapping = {i + 1: f'Di{i + 1}' for i in range(34)}  

turbidity_final['tri_name'] = turbidity_final['tri_code'].map(tri_mapping)
turbidity_final['di_name'] = turbidity_final['di_code'].map(di_mapping)

turbidity_final = turbidity_final.drop(columns=['tri_code', 'di_code'])

turbidity_final

# %%
di_precursors = tables_dataframes['precursors'][tables_dataframes['precursors']['name'].str.startswith('Di')].rename(
    columns={'name': 'di_name', 'smiles': 'di_smiles'}
)
tri_precursors = tables_dataframes['precursors'][tables_dataframes['precursors']['name'].str.startswith('Tri')].rename(
    columns={'name': 'tri_name', 'smiles': 'tri_smiles'}
)

turbidity_final = turbidity_final.merge(di_precursors[['di_name', 'di_smiles']], on='di_name', how='left')
turbidity_final = turbidity_final.merge(tri_precursors[['tri_name', 'tri_smiles']], on='tri_name', how='left')

turbidity_final

# %%
duplicates = turbidity_final[turbidity_final.duplicated(subset=['di_smiles', 'tri_smiles', 'di_name', 'tri_name'])]
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, precursor_combination, plate_number, turbidity, turbidity_label, turbidity_binary, tri_name, di_name, di_smiles, tri_smiles]
# Index: []

# %%
duplicates = turbidity_final[turbidity_final.duplicated(subset=['di_smiles', 'tri_smiles'])]
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, precursor_combination, plate_number, turbidity, turbidity_label, turbidity_binary, tri_name, di_name, di_smiles, tri_smiles]
# Index: []

# %%
turbidity_final.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')

# %% [markdown]
# # Features augmentation

# %%
import pubchempy as pcp

# %%
def get_compound_features(smiles):
    try:
        compound = pcp.get_compounds(smiles, 'smiles')[0]  
        return {
            'charge': compound.charge,
            'complexity': compound.complexity,
            'covalent_unit_count': compound.covalent_unit_count,
            'defined_atom_stereo_count': compound.defined_atom_stereo_count,
            'defined_bond_stereo_count': compound.defined_bond_stereo_count,
            'exact_mass': compound.exact_mass,
            'h_bond_acceptor_count': compound.h_bond_acceptor_count,
            'h_bond_donor_count': compound.h_bond_donor_count,
            'heavy_atom_count': compound.heavy_atom_count,
            'xlogp': compound.xlogp,
            'molecular_weight': compound.molecular_weight,
            'rotatable_bond_count': compound.rotatable_bond_count,
            'tpsa': compound.tpsa
        }
    except Exception as e:
        print(f"Error retrieving data for SMILES '{smiles}': {e}")
        return {key: None for key in [
            'charge', 'complexity', 'covalent_unit_count',
            'defined_atom_stereo_count', 'defined_bond_stereo_count', 'exact_mass',
            'h_bond_acceptor_count', 'h_bond_donor_count', 'heavy_atom_count', 'xlogp',
            'molecular_weight', 'rotatable_bond_count', 'tpsa'
        ]}

df_di_features = turbidity_final['di_smiles'].apply(get_compound_features).apply(pd.Series)
df_tri_features = turbidity_final['tri_smiles'].apply(get_compound_features).apply(pd.Series)

turbidity_final = pd.concat([turbidity_final, df_di_features.add_prefix('di_'), df_tri_features.add_prefix('tri_')], axis=1)

turbidity_final

# %%
turbidity_final
# Out:
#      Unnamed: 0.1  Unnamed: 0 precursor_combination  plate_number   turbidity  \
# 0               0           0                    A1             1   89.389731
# 1               1           1                    A2             1   95.423764
# 2               2           2                    A3             1   85.608188
# 3               3           3                    A4             1  100.885813
# 4               4           4                    A5             1  104.259992
# 5               5           5                    A6             1   74.239664
# 6               6           6                    A7             1   79.863862
# 7               7           7                    A8             1  103.709100
# 8               8           8                    A9             3   70.603576
# 9               9           9                   A10             3  104.687332
# 10             10          10                   A11             3   76.992759
# 11             11          11                   A12             3  100.924690
# 12             12          12                   A13             3   78.258283
# 13             13          13                   A14             3   75.354533
# 14             14          14                   A15             3   77.935484
# 15             15          15                   A16             3   73.448411
# 16             16          16                    B1             1   68.010419
# 17             17          17                    B2             1   51.066494
# 18             18          18                    B3             1  108.901599
# 19             19          19                    B4             1   57.661728
# 20             20          20                    B5             1   53.121768
# 21             21          21                    B6             1   53.718762
# 22             22          22                    B7             1   52.298704
# 23             23          23                    B8             1   80.471230
# 24             24          24                    B9             3  121.550919
# 25             25          25                   B10             3   56.594810
# 26             26          26                   B11             3  106.769737
# 27             27          27                   B12             3   74.070755
# 28             28          28                   B13             3   52.431722
# 29             29          29                   B14             3   68.639718
# 30             30          30                   B15             3   53.199301
# 31             31          31                   B16             3   60.090362
# 32             32          32                    C1             1   52.056282
# 33             33          33                    C2             1   52.855981
# 34             34          34                    C3             1   64.754220
# 35             35          35                    C4             1   53.913454
# 36             36          36                    C5             1   51.803978
# 37             37          37                    C6             1   74.333682
# 38             38          38                    C7             1   66.687181
# 39             39          39                    C8             1   58.966809
# 40             40          40                    C9             3   68.093250
# 41             41          41                   C10             3   56.597247
# 42             42          42                   C11             3   49.923442
# 43             43          43                   C12             3   57.361438
# 44             44          44                   C13             3   55.526622
# 45             45          45                   C14             3   70.217743
# 46             46          46                   C15             3   54.010949
# 47             47          47                   C16             3   56.366366
# 48             48          48                    D1             1  100.039015
# 49             49          49                    D2             1   46.124272
# 50             50          50                    D3             1   47.064902
# 51             51          51                    D4             1   57.558124
# 52             52          52                    D5             1   55.472413
# 53             53          53                    D6             1   56.476655
# 54             54          54                    D7             1   46.903339
# 55             55          55                    D8             1   55.673726
# 56             56          56                    D9             3   61.862173
# 57             57          57                   D10             3   55.890271
# 58             58          58                   D11             3   52.376800
# 59             59          59                   D12             3   59.753959
# 60             60          60                   D13             3   54.454255
# 61             61          61                   D14             3   57.572733
# 62             62          62                   D15             3   55.069114
# 63             63          63                   D16             3   58.446604
# 19           turbid                 0     TriB     Di4
# 20        dissolved                 1     TriB     Di5
# 21        dissolved                 1     TriB     Di6
# 22        dissolved                 1     TriB     Di7
# 23           turbid                 0     TriB     Di8
# 24           turbid                 0     TriB     Di9
# 25           turbid                 0     TriB    Di10
# 26           turbid                 0     TriB    Di11
# 27           turbid                 0     TriB    Di12
# 28        dissolved                 1     TriB    Di13
# 29           turbid                 0     TriB    Di14
# 30        dissolved                 1     TriB    Di15
# 31           turbid                 0     TriB    Di16
# 32        dissolved                 1     TriC     Di1
# 33        dissolved                 1     TriC     Di2
# 34           turbid                 0     TriC     Di3
# 35        dissolved                 1     TriC     Di4
# 36        dissolved                 1     TriC     Di5
# 37           turbid                 0     TriC     Di6
# 38           turbid                 0     TriC     Di7
# 39           turbid                 0     TriC     Di8
# 40           turbid                 0     TriC     Di9
# 41           turbid                 0     TriC    Di10
# 42        dissolved                 1     TriC    Di11
# 43           turbid                 0     TriC    Di12
# 44           turbid                 0     TriC    Di13
# 45           turbid                 0     TriC    Di14
# 46        dissolved                 1     TriC    Di15
# 47           turbid                 0     TriC    Di16
# 48           turbid                 0     TriD     Di1
# 49        dissolved                 1     TriD     Di2
# 50        dissolved                 1     TriD     Di3
# 51           turbid                 0     TriD     Di4
# 52           turbid                 0     TriD     Di5
# 53           turbid                 0     TriD     Di6
# 54        dissolved                 1     TriD     Di7
# 55           turbid                 0     TriD     Di8
# 56           turbid                 0     TriD     Di9
# 57           turbid                 0     TriD    Di10
# 58        dissolved                 1     TriD    Di11
# 59           turbid                 0     TriD    Di12
# 60        dissolved                 1     TriD    Di13
# 61           turbid                 0     TriD    Di14
# 62        dissolved                 1     TriD    Di15
# 63           turbid                 0     TriD    Di16
# 64           turbid                 0     TriE     Di1
# 65           turbid                 0     TriE     Di2
# 66           turbid                 0     TriE     Di3
# 67           turbid                 0     TriE     Di4
# 68           turbid                 0     TriE     Di5
# 69        dissolved                 1     TriE     Di6
# 70           turbid                 0     TriE     Di7
# 71           turbid                 0     TriE     Di8
# 72        dissolved                 1     TriE     Di9
# 73           turbid                 0     TriE    Di10
# 74           turbid                 0     TriE    Di11
# 75           turbid                 0     TriE    Di12
# 76           turbid                 0     TriE    Di13
# 77           turbid                 0     TriE    Di14
# 78        dissolved                 1     TriE    Di15
# 79           turbid                 0     TriE    Di16
# 80           turbid                 0     TriF     Di1
# 81           turbid                 0     TriF     Di2
# 82           turbid                 0     TriF     Di3
# 83           turbid                 0     TriF     Di4
# 84           turbid                 0     TriF     Di5
# 85           turbid                 0     TriF     Di6
# 86           turbid                 0     TriF     Di7
# 87           turbid                 0     TriF     Di8
# 88           turbid                 0     TriF     Di9
# 89           turbid                 0     TriF    Di10
# 90           turbid                 0     TriF    Di11
# 91           turbid                 0     TriF    Di12
# 92           turbid                 0     TriF    Di13
# 93           turbid                 0     TriF    Di14
# 94           turbid                 0     TriF    Di15
# 95           turbid                 0     TriF    Di16
# 96           turbid                 0     TriG    Di17
# 97        dissolved                 1     TriG    Di18
# 98           turbid                 0     TriG    Di19
# 99        dissolved                 1     TriG    Di20
# 100          turbid                 0     TriG    Di21
# 101          turbid                 0     TriG    Di22
# 102          turbid                 0     TriG    Di23
# 103          turbid                 0     TriG    Di24
# 104       dissolved                 1     TriG    Di25
# 105       dissolved                 1     TriG    Di26
# 106       dissolved                 1     TriG    Di27
# 107          turbid                 0     TriG    Di28
# 108       dissolved                 1     TriG    Di29
# 109       dissolved                 1     TriG    Di30
# 110       dissolved                 1     TriG    Di31
# 111       dissolved                 1     TriG    Di32
# 112       dissolved                 1     TriG    Di33
# 113       dissolved                 1     TriG    Di34
# 114          turbid                 0     TriH    Di17
# 115          turbid                 0     TriH    Di18
# 116          turbid                 0     TriH    Di19
# 117          turbid                 0     TriH    Di20
# 118          turbid                 0     TriH    Di21
# 119          turbid                 0     TriH    Di22
# 120          turbid                 0     TriH    Di23
# 121          turbid                 0     TriH    Di24
# 122       dissolved                 1     TriH    Di25
# 123       dissolved                 1     TriH    Di26
# 124       dissolved                 1     TriH    Di27
# 125       dissolved                 1     TriH    Di28
# 126       dissolved                 1     TriH    Di29
# 127       dissolved                 1     TriH    Di30
# 128       dissolved                 1     TriH    Di31
# 129       dissolved                 1     TriH    Di32
# 130       dissolved                 1     TriH    Di33
# 131       dissolved                 1     TriH    Di34
# 132          turbid                 0     TriI    Di17
# 133          turbid                 0     TriI    Di18
# 134          turbid                 0     TriI    Di19
# 135          turbid                 0     TriI    Di20
# 136          turbid                 0     TriI    Di21
# 137          turbid                 0     TriI    Di22
# 138          turbid                 0     TriI    Di23
# 139          turbid                 0     TriI    Di24
# 140       dissolved                 1     TriI    Di25
# 141       dissolved                 1     TriI    Di26
# 142       dissolved                 1     TriI    Di27
# 143       dissolved                 1     TriI    Di28
# 144       dissolved                 1     TriI    Di29
# 145       dissolved                 1     TriI    Di30
# 146       dissolved                 1     TriI    Di31
# 147          turbid                 0     TriI    Di32
# 148       dissolved                 1     TriI    Di33
# 149       dissolved                 1     TriI    Di34
# 150          turbid                 0     TriJ    Di17
# 151          turbid                 0     TriJ    Di18
# 152          turbid                 0     TriJ    Di19
# 153          turbid                 0     TriJ    Di20
# 154          turbid                 0     TriJ    Di21
# 155          turbid                 0     TriJ    Di22
# 156          turbid                 0     TriJ    Di23
# 157          turbid                 0     TriJ    Di24
# 158       dissolved                 1     TriJ    Di25
# 159       dissolved                 1     TriJ    Di26
# 160       dissolved                 1     TriJ    Di27
# 161       dissolved                 1     TriJ    Di28
# 162       dissolved                 1     TriJ    Di29
# 163       dissolved                 1     TriJ    Di30
# 164       dissolved                 1     TriJ    Di31
# 165       dissolved                 1     TriJ    Di32
# 166       dissolved                 1     TriJ    Di33
# 167       dissolved                 1     TriJ    Di34
# 168          turbid                 0     TriK    Di17
# 169          turbid                 0     TriK    Di18
# 170          turbid                 0     TriK    Di19
# 171          turbid                 0     TriK    Di20
# 172          turbid                 0     TriK    Di21
# 173          turbid                 0     TriK    Di22
# 174          turbid                 0     TriK    Di23
# 175          turbid                 0     TriK    Di24
# 176       dissolved                 1     TriK    Di25
# 177       dissolved                 1     TriK    Di26
# 178          turbid                 0     TriK    Di27
# 179          turbid                 0     TriK    Di28
# 180       dissolved                 1     TriK    Di29
# 181       dissolved                 1     TriK    Di30
# 182       dissolved                 1     TriK    Di31
# 183       dissolved                 1     TriK    Di32
# 184       dissolved                 1     TriK    Di33
# 185       dissolved                 1     TriK    Di34
# 186          turbid                 0     TriL    Di17
# 187          turbid                 0     TriL    Di18
# 188          turbid                 0     TriL    Di19
# 189          turbid                 0     TriL    Di20
# 190          turbid                 0     TriL    Di21
# 191          turbid                 0     TriL    Di22
# 192          turbid                 0     TriL    Di23
# 193          turbid                 0     TriL    Di24
# 194       dissolved                 1     TriL    Di25
# 195       dissolved                 1     TriL    Di26
# 196          turbid                 0     TriL    Di27
# 197       dissolved                 1     TriL    Di28
# 198       dissolved                 1     TriL    Di29
# 199       dissolved                 1     TriL    Di30
# 200          turbid                 0     TriL    Di31
# 201       dissolved                 1     TriL    Di32
# 202       dissolved                 1     TriL    Di33
# 203       dissolved                 1     TriL    Di34
# 204          turbid                 0     TriM    Di17
# 205       dissolved                 1     TriM    Di18
# 206          turbid                 0     TriM    Di19
# 207       dissolved                 1     TriM    Di20
# 208          turbid                 0     TriM    Di21
# 209          turbid                 0     TriM    Di22
# 210          turbid                 0     TriM    Di23
# 211       dissolved                 1     TriM    Di24
# 212       dissolved                 1     TriM    Di25
# 213       dissolved                 1     TriM    Di26
# 214       dissolved                 1     TriM    Di27
# 215       dissolved                 1     TriM    Di28
# 216       dissolved                 1     TriM    Di29
# 217       dissolved                 1     TriM    Di30
# 218       dissolved                 1     TriM    Di31
# 219       dissolved                 1     TriM    Di32
# 220       dissolved                 1     TriM    Di33
# 221       dissolved                 1     TriM    Di34
# 222          turbid                 0     TriN    Di17
# 223       dissolved                 1     TriN    Di18
# 224       dissolved                 1     TriN    Di19
# 225       dissolved                 1     TriN    Di20
# 226       dissolved                 1     TriN    Di21
# 227          turbid                 0     TriN    Di22
# 228          turbid                 0     TriN    Di23
# 229       dissolved                 1     TriN    Di24
# 230       dissolved                 1     TriN    Di25
# 231       dissolved                 1     TriN    Di26
# 232       dissolved                 1     TriN    Di27
# 233       dissolved                 1     TriN    Di28
# 234       dissolved                 1     TriN    Di29
# 235       dissolved                 1     TriN    Di30
# 236       dissolved                 1     TriN    Di31
# 237       dissolved                 1     TriN    Di32
# 238       dissolved                 1     TriN    Di33
# 239       dissolved                 1     TriN    Di34
# 240          turbid                 0     TriO    Di17
# 241          turbid                 0     TriO    Di18
# 242          turbid                 0     TriO    Di19
# 243       dissolved                 1     TriO    Di20
# 244          turbid                 0     TriO    Di21
# 245          turbid                 0     TriO    Di22
# 246          turbid                 0     TriO    Di23
# 247       dissolved                 1     TriO    Di24
# 248       dissolved                 1     TriO    Di25
# 249       dissolved                 1     TriO    Di26
# 250       dissolved                 1     TriO    Di27
# 251       dissolved                 1     TriO    Di28
# 252       dissolved                 1     TriO    Di29
# 253       dissolved                 1     TriO    Di30
# 254       dissolved                 1     TriO    Di31
# 255          turbid                 0     TriO    Di32
# 256       dissolved                 1     TriO    Di33
# 257       dissolved                 1     TriO    Di34
# 258          turbid                 0     TriP    Di17
# 259          turbid                 0     TriP    Di18
# 260          turbid                 0     TriP    Di19
# 261          turbid                 0     TriP    Di20
# 262          turbid                 0     TriP    Di21
# 263          turbid                 0     TriP    Di22
# 264          turbid                 0     TriP    Di23
# 265       dissolved                 1     TriP    Di24
# 266       dissolved                 1     TriP    Di25
# 267       dissolved                 1     TriP    Di26
# 268       dissolved                 1     TriP    Di27
# 269       dissolved                 1     TriP    Di28
# 270       dissolved                 1     TriP    Di29
# 271       dissolved                 1     TriP    Di30
# 272       dissolved                 1     TriP    Di31
# 273          turbid                 0     TriP    Di32
# 274       dissolved                 1     TriP    Di33
# 275       dissolved                 1     TriP    Di34
# 276          turbid                 0     TriQ    Di17
# 277       dissolved                 1     TriQ    Di18
# 278          turbid                 0     TriQ    Di19
# 279       dissolved                 1     TriQ    Di20
# 280          turbid                 0     TriQ    Di21
# 281          turbid                 0     TriQ    Di22
# 282          turbid                 0     TriQ    Di23
# 283       dissolved                 1     TriQ    Di24
# 284       dissolved                 1     TriQ    Di25
# 285       dissolved                 1     TriQ    Di26
# 286          turbid                 0     TriQ    Di27
# 287       dissolved                 1     TriQ    Di28
# 288       dissolved                 1     TriQ    Di29
# 289       dissolved                 1     TriQ    Di30
# 290       dissolved                 1     TriQ    Di31
# 291          turbid                 0     TriQ    Di32
# 292       dissolved                 1     TriQ    Di33
# 293          turbid                 0     TriQ    Di34
# 294       dissolved                 1     TriR    Di17
# 295       dissolved                 1     TriR    Di18
# 296          turbid                 0     TriR    Di19
# 297       dissolved                 1     TriR    Di20
# 298          turbid                 0     TriR    Di21
# 299       dissolved                 1     TriR    Di22
# 300       dissolved                 1     TriR    Di23
# 301       dissolved                 1     TriR    Di24
# 302       dissolved                 1     TriR    Di25
# 303       dissolved                 1     TriR    Di26
# 304       dissolved                 1     TriR    Di27
# 305       dissolved                 1     TriR    Di28
# 306       dissolved                 1     TriR    Di29
# 307       dissolved                 1     TriR    Di30
# 308       dissolved                 1     TriR    Di31
# 309       dissolved                 1     TriR    Di32
# 310       dissolved                 1     TriR    Di33
# 311       dissolved                 1     TriR    Di34
# 312       dissolved                 1     TriS    Di17
# 313       dissolved                 1     TriS    Di18
# ...
# 112               162.14                       3.0      51.2
# 113               162.14                       3.0      51.2
# 114                390.4                       6.0      51.2
# 115                390.4                       6.0      51.2
# 116                390.4                       6.0      51.2
# 117                390.4                       6.0      51.2
# 118                390.4                       6.0      51.2
# 119                390.4                       6.0      51.2
# 120                390.4                       6.0      51.2
# 121                390.4                       6.0      51.2
# 122                390.4                       6.0      51.2
# 123                390.4                       6.0      51.2
# 124                390.4                       6.0      51.2
# 125                390.4                       6.0      51.2
# 126                390.4                       6.0      51.2
# 127                390.4                       6.0      51.2
# 128                390.4                       6.0      51.2
# 129                390.4                       6.0      51.2
# 130                390.4                       6.0      51.2
# 131                390.4                       6.0      51.2
# 132               178.14                       3.0      71.4
# 133               178.14                       3.0      71.4
# 134               178.14                       3.0      71.4
# 135               178.14                       3.0      71.4
# 136               178.14                       3.0      71.4
# 137               178.14                       3.0      71.4
# 138               178.14                       3.0      71.4
# 139               178.14                       3.0      71.4
# 140               178.14                       3.0      71.4
# 141               178.14                       3.0      71.4
# 142               178.14                       3.0      71.4
# 143               178.14                       3.0      71.4
# 144               178.14                       3.0      71.4
# 145               178.14                       3.0      71.4
# 146               178.14                       3.0      71.4
# 147               178.14                       3.0      71.4
# 148               178.14                       3.0      71.4
# 149               178.14                       3.0      71.4
# 150                329.3                       6.0      54.4
# 151                329.3                       6.0      54.4
# 152                329.3                       6.0      54.4
# 153                329.3                       6.0      54.4
# 154                329.3                       6.0      54.4
# 155                329.3                       6.0      54.4
# 156                329.3                       6.0      54.4
# 157                329.3                       6.0      54.4
# 158                329.3                       6.0      54.4
# 159                329.3                       6.0      54.4
# 160                329.3                       6.0      54.4
# 161                329.3                       6.0      54.4
# 162                329.3                       6.0      54.4
# 163                329.3                       6.0      54.4
# 164                329.3                       6.0      54.4
# 165                329.3                       6.0      54.4
# 166                329.3                       6.0      54.4
# 167                329.3                       6.0      54.4
# 168                393.4                       6.0      89.9
# 169                393.4                       6.0      89.9
# 170                393.4                       6.0      89.9
# 171                393.4                       6.0      89.9
# 172                393.4                       6.0      89.9
# 173                393.4                       6.0      89.9
# 174                393.4                       6.0      89.9
# 175                393.4                       6.0      89.9
# 176                393.4                       6.0      89.9
# 177                393.4                       6.0      89.9
# 178                393.4                       6.0      89.9
# 179                393.4                       6.0      89.9
# 180                393.4                       6.0      89.9
# 181                393.4                       6.0      89.9
# 182                393.4                       6.0      89.9
# 183                393.4                       6.0      89.9
# 184                393.4                       6.0      89.9
# 185                393.4                       6.0      89.9
# 186                462.5                       9.0      51.2
# 187                462.5                       9.0      51.2
# 188                462.5                       9.0      51.2
# 189                462.5                       9.0      51.2
# 190                462.5                       9.0      51.2
# 191                462.5                       9.0      51.2
# 192                462.5                       9.0      51.2
# 193                462.5                       9.0      51.2
# 194                462.5                       9.0      51.2
# 195                462.5                       9.0      51.2
# 196                462.5                       9.0      51.2
# 197                462.5                       9.0      51.2
# 198                462.5                       9.0      51.2
# 199                462.5                       9.0      51.2
# 200                462.5                       9.0      51.2
# 201                462.5                       9.0      51.2
# 202                462.5                       9.0      51.2
# 203                462.5                       9.0      51.2
# 204                390.4                       6.0      51.2
# 205                390.4                       6.0      51.2
# 206                390.4                       6.0      51.2
# 207                390.4                       6.0      51.2
# 208                390.4                       6.0      51.2
# 209                390.4                       6.0      51.2
# 210                390.4                       6.0      51.2
# 211                390.4                       6.0      51.2
# 212                390.4                       6.0      51.2
# 213                390.4                       6.0      51.2
# 214                390.4                       6.0      51.2
# 215                390.4                       6.0      51.2
# 216                390.4                       6.0      51.2
# 217                390.4                       6.0      51.2
# 218                390.4                       6.0      51.2
# 219                390.4                       6.0      51.2
# 220                390.4                       6.0      51.2
# 221                390.4                       6.0      51.2
# 222                390.4                       6.0      51.2
# 223                390.4                       6.0      51.2
# 224                390.4                       6.0      51.2
# 225                390.4                       6.0      51.2
# 226                390.4                       6.0      51.2
# 227                390.4                       6.0      51.2
# 228                390.4                       6.0      51.2
# 229                390.4                       6.0      51.2
# 230                390.4                       6.0      51.2
# 231                390.4                       6.0      51.2
# 232                390.4                       6.0      51.2
# 233                390.4                       6.0      51.2
# 234                390.4                       6.0      51.2
# 235                390.4                       6.0      51.2
# 236                390.4                       6.0      51.2
# 237                390.4                       6.0      51.2
# 238                390.4                       6.0      51.2
# 239                390.4                       6.0      51.2
# 240                408.5                       6.0     136.0
# 241                408.5                       6.0     136.0
# 242                408.5                       6.0     136.0
# 243                408.5                       6.0     136.0
# 244                408.5                       6.0     136.0
# 245                408.5                       6.0     136.0
# 246                408.5                       6.0     136.0
# 247                408.5                       6.0     136.0
# 248                408.5                       6.0     136.0
# 249                408.5                       6.0     136.0
# 250                408.5                       6.0     136.0
# 251                408.5                       6.0     136.0
# 252                408.5                       6.0     136.0
# 253                408.5                       6.0     136.0
# 254                408.5                       6.0     136.0
# 255                408.5                       6.0     136.0
# 256                408.5                       6.0     136.0
# 257                408.5                       6.0     136.0
# 258                360.3                       6.0      90.6
# 259                360.3                       6.0      90.6
# 260                360.3                       6.0      90.6
# 261                360.3                       6.0      90.6
# 262                360.3                       6.0      90.6
# 263                360.3                       6.0      90.6
# 264                360.3                       6.0      90.6
# 265                360.3                       6.0      90.6
# 266                360.3                       6.0      90.6
# 267                360.3                       6.0      90.6
# 268                360.3                       6.0      90.6
# 269                360.3                       6.0      90.6
# 270                360.3                       6.0      90.6
# 271                360.3                       6.0      90.6
# 272                360.3                       6.0      90.6
# 273                360.3                       6.0      90.6
# 274                360.3                       6.0      90.6
# 275                360.3                       6.0      90.6
# 276                  NaN                       NaN       NaN
# 277                  NaN                       NaN       NaN
# 278                  NaN                       NaN       NaN
# 279                  NaN                       NaN       NaN
# 280                  NaN                       NaN       NaN
# 281                  NaN                       NaN       NaN
# 282                  NaN                       NaN       NaN
# 283                  NaN                       NaN       NaN
# 284                  NaN                       NaN       NaN
# 285                  NaN                       NaN       NaN
# 286                  NaN                       NaN       NaN
# 287                  NaN                       NaN       NaN
# 288                  NaN                       NaN       NaN
# 289                  NaN                       NaN       NaN
# 290                  NaN                       NaN       NaN
# 291                  NaN                       NaN       NaN
# 292                  NaN                       NaN       NaN
# 293                  NaN                       NaN       NaN
# 294                480.5                      12.0      78.9
# 295                480.5                      12.0      78.9
# 296                480.5                      12.0      78.9
# 297                480.5                      12.0      78.9
# 298                480.5                      12.0      78.9
# 299                480.5                      12.0      78.9
# 300                480.5                      12.0      78.9
# 301                480.5                      12.0      78.9
# 302                480.5                      12.0      78.9
# 303                480.5                      12.0      78.9
# 304                480.5                      12.0      78.9
# 305                480.5                      12.0      78.9
# 306                480.5                      12.0      78.9
# 307                480.5                      12.0      78.9
# 308                480.5                      12.0      78.9
# 309                480.5                      12.0      78.9
# 310                480.5                      12.0      78.9
# 311                480.5                      12.0      78.9
# 312               262.26                       5.0      51.2
# 313               262.26                       5.0      51.2
# 314               262.26                       5.0      51.2
# 315               262.26                       5.0      51.2
# 316               262.26                       5.0      51.2
# 317               262.26                       5.0      51.2
# 318               262.26                       5.0      51.2
# 319               262.26                       5.0      51.2
# 320               262.26                       5.0      51.2
# 321               262.26                       5.0      51.2
# 322               262.26                       5.0      51.2
# 323               262.26                       5.0      51.2
# 324               262.26                       5.0      51.2
# 325               262.26                       5.0      51.2
# 326               262.26                       5.0      51.2
# 327               262.26                       5.0      51.2
# 328               262.26                       5.0      51.2
# 329               262.26                       5.0      51.2
# 330               210.14                       3.0     112.0
# 331               210.14                       3.0     112.0
# 332               210.14                       3.0     112.0
# 333               210.14                       3.0     112.0
# 334               210.14                       3.0     112.0
# 335               210.14                       3.0     112.0
# 336               210.14                       3.0     112.0
# 337               210.14                       3.0     112.0
# 338               210.14                       3.0     112.0
# 339               210.14                       3.0     112.0
# 340               210.14                       3.0     112.0
# 341               210.14                       3.0     112.0
# 342               210.14                       3.0     112.0
# 343               210.14                       3.0     112.0
# 344               210.14                       3.0     112.0
# 345               210.14                       3.0     112.0
# 346               210.14                       3.0     112.0
# 347               210.14                       3.0     112.0
# 348                  NaN                       NaN       NaN
# 349                  NaN                       NaN       NaN
# 350                  NaN                       NaN       NaN
# 351                  NaN                       NaN       NaN
# 352                  NaN                       NaN       NaN
# 353                  NaN                       NaN       NaN
# 354                  NaN                       NaN       NaN
# 355                  NaN                       NaN       NaN
# 356                  NaN                       NaN       NaN
# 357                  NaN                       NaN       NaN
# 358                  NaN                       NaN       NaN
# 359                  NaN                       NaN       NaN
# 360                  NaN                       NaN       NaN
# 361                  NaN                       NaN       NaN
# 362                  NaN                       NaN       NaN
# 363                  NaN                       NaN       NaN
# 364                  NaN                       NaN       NaN
# 365                  NaN                       NaN       NaN

# %%
turbidity_final.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')

# %% [markdown]
# TriU and TriQ cannot be feature-augmented

# %% [markdown]
# Replacing TriU from:O=Cc1ccc(C=Cc2cc(C=Cc3ccc(C=O)cc3)cc(C=Cc3ccc(C=O)cc3)c2)cc1 to: C1=CC(=CC=C1/C=C/C2=CC(=CC(=C2)/C=C/C3=CC=C(C=C3)C=O)/C=C/C4=CC=C(C=C4)C=O)C=O

# %%
new_tri_smiles = 'C1=CC(=CC=C1/C=C/C2=CC(=CC(=C2)/C=C/C3=CC=C(C=C3)C=O)/C=C/C4=CC=C(C=C4)C=O)C=O'

turbidity_final.loc[turbidity_final['tri_name'] == 'TriU', 'tri_smiles'] = new_tri_smiles

turbidity_final

# %%
kept = [
    'Unnamed: 0.1',
    'Unnamed: 0',
    'precursor_combination',
    'plate_number',
    'turbidity',
    'turbidity_label',
    'turbidity_binary',
    'tri_name',
    'di_name',
    'di_smiles',
    'tri_smiles'
]

turbidity_final = turbidity_final[kept]

# %%
df_di_features = turbidity_final['di_smiles'].apply(get_compound_features).apply(pd.Series)
df_tri_features = turbidity_final['tri_smiles'].apply(get_compound_features).apply(pd.Series)

turbidity_final = pd.concat([turbidity_final, df_di_features.add_prefix('di_'), df_tri_features.add_prefix('tri_')], axis=1)

turbidity_final
# Out:
#      Unnamed: 0.1  Unnamed: 0 precursor_combination  plate_number   turbidity  \
# 0               0           0                    A1             1   89.389731
# 1               1           1                    A2             1   95.423764
# 2               2           2                    A3             1   85.608188
# 3               3           3                    A4             1  100.885813
# 4               4           4                    A5             1  104.259992
# 5               5           5                    A6             1   74.239664
# 6               6           6                    A7             1   79.863862
# 7               7           7                    A8             1  103.709100
# 8               8           8                    A9             3   70.603576
# 9               9           9                   A10             3  104.687332
# 10             10          10                   A11             3   76.992759
# 11             11          11                   A12             3  100.924690
# 12             12          12                   A13             3   78.258283
# 13             13          13                   A14             3   75.354533
# 14             14          14                   A15             3   77.935484
# 15             15          15                   A16             3   73.448411
# 16             16          16                    B1             1   68.010419
# 17             17          17                    B2             1   51.066494
# 18             18          18                    B3             1  108.901599
# 19             19          19                    B4             1   57.661728
# 20             20          20                    B5             1   53.121768
# 21             21          21                    B6             1   53.718762
# 22             22          22                    B7             1   52.298704
# 23             23          23                    B8             1   80.471230
# 24             24          24                    B9             3  121.550919
# 25             25          25                   B10             3   56.594810
# 26             26          26                   B11             3  106.769737
# 27             27          27                   B12             3   74.070755
# 28             28          28                   B13             3   52.431722
# 29             29          29                   B14             3   68.639718
# 30             30          30                   B15             3   53.199301
# 31             31          31                   B16             3   60.090362
# 32             32          32                    C1             1   52.056282
# 33             33          33                    C2             1   52.855981
# 34             34          34                    C3             1   64.754220
# 35             35          35                    C4             1   53.913454
# 36             36          36                    C5             1   51.803978
# 37             37          37                    C6             1   74.333682
# 38             38          38                    C7             1   66.687181
# 39             39          39                    C8             1   58.966809
# 40             40          40                    C9             3   68.093250
# 41             41          41                   C10             3   56.597247
# 42             42          42                   C11             3   49.923442
# 43             43          43                   C12             3   57.361438
# 44             44          44                   C13             3   55.526622
# 45             45          45                   C14             3   70.217743
# 46             46          46                   C15             3   54.010949
# 47             47          47                   C16             3   56.366366
# 48             48          48                    D1             1  100.039015
# 49             49          49                    D2             1   46.124272
# 50             50          50                    D3             1   47.064902
# 51             51          51                    D4             1   57.558124
# 52             52          52                    D5             1   55.472413
# 53             53          53                    D6             1   56.476655
# 54             54          54                    D7             1   46.903339
# 55             55          55                    D8             1   55.673726
# 56             56          56                    D9             3   61.862173
# 57             57          57                   D10             3   55.890271
# 58             58          58                   D11             3   52.376800
# 59             59          59                   D12             3   59.753959
# 60             60          60                   D13             3   54.454255
# 61             61          61                   D14             3   57.572733
# 62             62          62                   D15             3   55.069114
# 63             63          63                   D16             3   58.446604
# 64             64          64                    E1             1   77.143650
# 65             65          65                    E2             1   56.025140
# 66             66          66                    E3             1   84.833226
# 67             67          67                    E4             1   56.368840
# 68             68          68                    E5             1   78.579703
# 69             69          69                    E6             1   49.854532
# 70             70          70                    E7             1   70.651918
# 71             71          71                    E8             1   62.120374
# 72             72          72                    E9             3   54.734559
# 28        dissolved                 1     TriB    Di13
# 29           turbid                 0     TriB    Di14
# 30        dissolved                 1     TriB    Di15
# 31           turbid                 0     TriB    Di16
# 32        dissolved                 1     TriC     Di1
# 33        dissolved                 1     TriC     Di2
# 34           turbid                 0     TriC     Di3
# 35        dissolved                 1     TriC     Di4
# 36        dissolved                 1     TriC     Di5
# 37           turbid                 0     TriC     Di6
# 38           turbid                 0     TriC     Di7
# 39           turbid                 0     TriC     Di8
# 40           turbid                 0     TriC     Di9
# 41           turbid                 0     TriC    Di10
# 42        dissolved                 1     TriC    Di11
# 43           turbid                 0     TriC    Di12
# 44           turbid                 0     TriC    Di13
# 45           turbid                 0     TriC    Di14
# 46        dissolved                 1     TriC    Di15
# 47           turbid                 0     TriC    Di16
# 48           turbid                 0     TriD     Di1
# 49        dissolved                 1     TriD     Di2
# 50        dissolved                 1     TriD     Di3
# 51           turbid                 0     TriD     Di4
# 52           turbid                 0     TriD     Di5
# 53           turbid                 0     TriD     Di6
# 54        dissolved                 1     TriD     Di7
# 55           turbid                 0     TriD     Di8
# 56           turbid                 0     TriD     Di9
# 57           turbid                 0     TriD    Di10
# 58        dissolved                 1     TriD    Di11
# 59           turbid                 0     TriD    Di12
# 60        dissolved                 1     TriD    Di13
# 61           turbid                 0     TriD    Di14
# 62        dissolved                 1     TriD    Di15
# 63           turbid                 0     TriD    Di16
# 64           turbid                 0     TriE     Di1
# 65           turbid                 0     TriE     Di2
# 66           turbid                 0     TriE     Di3
# 67           turbid                 0     TriE     Di4
# 68           turbid                 0     TriE     Di5
# 69        dissolved                 1     TriE     Di6
# 70           turbid                 0     TriE     Di7
# 71           turbid                 0     TriE     Di8
# 72        dissolved                 1     TriE     Di9
# 73           turbid                 0     TriE    Di10
# 74           turbid                 0     TriE    Di11
# 75           turbid                 0     TriE    Di12
# 76           turbid                 0     TriE    Di13
# 77           turbid                 0     TriE    Di14
# 78        dissolved                 1     TriE    Di15
# 79           turbid                 0     TriE    Di16
# 80           turbid                 0     TriF     Di1
# 81           turbid                 0     TriF     Di2
# 82           turbid                 0     TriF     Di3
# 83           turbid                 0     TriF     Di4
# 84           turbid                 0     TriF     Di5
# 85           turbid                 0     TriF     Di6
# 86           turbid                 0     TriF     Di7
# 87           turbid                 0     TriF     Di8
# 88           turbid                 0     TriF     Di9
# 89           turbid                 0     TriF    Di10
# 90           turbid                 0     TriF    Di11
# 91           turbid                 0     TriF    Di12
# 92           turbid                 0     TriF    Di13
# 93           turbid                 0     TriF    Di14
# 94           turbid                 0     TriF    Di15
# 95           turbid                 0     TriF    Di16
# 96           turbid                 0     TriG    Di17
# 97        dissolved                 1     TriG    Di18
# 98           turbid                 0     TriG    Di19
# 99        dissolved                 1     TriG    Di20
# 100          turbid                 0     TriG    Di21
# 101          turbid                 0     TriG    Di22
# 102          turbid                 0     TriG    Di23
# 103          turbid                 0     TriG    Di24
# 104       dissolved                 1     TriG    Di25
# 105       dissolved                 1     TriG    Di26
# 106       dissolved                 1     TriG    Di27
# 107          turbid                 0     TriG    Di28
# 108       dissolved                 1     TriG    Di29
# 109       dissolved                 1     TriG    Di30
# 110       dissolved                 1     TriG    Di31
# 111       dissolved                 1     TriG    Di32
# 112       dissolved                 1     TriG    Di33
# 113       dissolved                 1     TriG    Di34
# 114          turbid                 0     TriH    Di17
# 115          turbid                 0     TriH    Di18
# 116          turbid                 0     TriH    Di19
# 117          turbid                 0     TriH    Di20
# 118          turbid                 0     TriH    Di21
# 119          turbid                 0     TriH    Di22
# 120          turbid                 0     TriH    Di23
# 121          turbid                 0     TriH    Di24
# 122       dissolved                 1     TriH    Di25
# 123       dissolved                 1     TriH    Di26
# 124       dissolved                 1     TriH    Di27
# 125       dissolved                 1     TriH    Di28
# 126       dissolved                 1     TriH    Di29
# 127       dissolved                 1     TriH    Di30
# 128       dissolved                 1     TriH    Di31
# 129       dissolved                 1     TriH    Di32
# 130       dissolved                 1     TriH    Di33
# 131       dissolved                 1     TriH    Di34
# 132          turbid                 0     TriI    Di17
# 133          turbid                 0     TriI    Di18
# 134          turbid                 0     TriI    Di19
# 135          turbid                 0     TriI    Di20
# 136          turbid                 0     TriI    Di21
# 137          turbid                 0     TriI    Di22
# 138          turbid                 0     TriI    Di23
# 139          turbid                 0     TriI    Di24
# 140       dissolved                 1     TriI    Di25
# 141       dissolved                 1     TriI    Di26
# 142       dissolved                 1     TriI    Di27
# 143       dissolved                 1     TriI    Di28
# 144       dissolved                 1     TriI    Di29
# 145       dissolved                 1     TriI    Di30
# 146       dissolved                 1     TriI    Di31
# 147          turbid                 0     TriI    Di32
# 148       dissolved                 1     TriI    Di33
# 149       dissolved                 1     TriI    Di34
# 150          turbid                 0     TriJ    Di17
# 151          turbid                 0     TriJ    Di18
# 152          turbid                 0     TriJ    Di19
# 153          turbid                 0     TriJ    Di20
# 154          turbid                 0     TriJ    Di21
# 155          turbid                 0     TriJ    Di22
# 156          turbid                 0     TriJ    Di23
# 157          turbid                 0     TriJ    Di24
# 158       dissolved                 1     TriJ    Di25
# 159       dissolved                 1     TriJ    Di26
# 160       dissolved                 1     TriJ    Di27
# 161       dissolved                 1     TriJ    Di28
# 162       dissolved                 1     TriJ    Di29
# 163       dissolved                 1     TriJ    Di30
# 164       dissolved                 1     TriJ    Di31
# 165       dissolved                 1     TriJ    Di32
# 166       dissolved                 1     TriJ    Di33
# 167       dissolved                 1     TriJ    Di34
# 168          turbid                 0     TriK    Di17
# 169          turbid                 0     TriK    Di18
# 170          turbid                 0     TriK    Di19
# 171          turbid                 0     TriK    Di20
# 172          turbid                 0     TriK    Di21
# 173          turbid                 0     TriK    Di22
# 174          turbid                 0     TriK    Di23
# 175          turbid                 0     TriK    Di24
# 176       dissolved                 1     TriK    Di25
# 177       dissolved                 1     TriK    Di26
# 178          turbid                 0     TriK    Di27
# 179          turbid                 0     TriK    Di28
# 180       dissolved                 1     TriK    Di29
# 181       dissolved                 1     TriK    Di30
# 182       dissolved                 1     TriK    Di31
# 183       dissolved                 1     TriK    Di32
# 184       dissolved                 1     TriK    Di33
# 185       dissolved                 1     TriK    Di34
# 186          turbid                 0     TriL    Di17
# 187          turbid                 0     TriL    Di18
# 188          turbid                 0     TriL    Di19
# 189          turbid                 0     TriL    Di20
# 190          turbid                 0     TriL    Di21
# 191          turbid                 0     TriL    Di22
# 192          turbid                 0     TriL    Di23
# 193          turbid                 0     TriL    Di24
# 194       dissolved                 1     TriL    Di25
# 195       dissolved                 1     TriL    Di26
# 196          turbid                 0     TriL    Di27
# 197       dissolved                 1     TriL    Di28
# 198       dissolved                 1     TriL    Di29
# 199       dissolved                 1     TriL    Di30
# 200          turbid                 0     TriL    Di31
# 201       dissolved                 1     TriL    Di32
# 202       dissolved                 1     TriL    Di33
# 203       dissolved                 1     TriL    Di34
# 204          turbid                 0     TriM    Di17
# 205       dissolved                 1     TriM    Di18
# 206          turbid                 0     TriM    Di19
# 207       dissolved                 1     TriM    Di20
# 208          turbid                 0     TriM    Di21
# 209          turbid                 0     TriM    Di22
# 210          turbid                 0     TriM    Di23
# 211       dissolved                 1     TriM    Di24
# 212       dissolved                 1     TriM    Di25
# 213       dissolved                 1     TriM    Di26
# 214       dissolved                 1     TriM    Di27
# 215       dissolved                 1     TriM    Di28
# 216       dissolved                 1     TriM    Di29
# 217       dissolved                 1     TriM    Di30
# 218       dissolved                 1     TriM    Di31
# 219       dissolved                 1     TriM    Di32
# 220       dissolved                 1     TriM    Di33
# 221       dissolved                 1     TriM    Di34
# 222          turbid                 0     TriN    Di17
# 223       dissolved                 1     TriN    Di18
# 224       dissolved                 1     TriN    Di19
# 225       dissolved                 1     TriN    Di20
# 226       dissolved                 1     TriN    Di21
# 227          turbid                 0     TriN    Di22
# 228          turbid                 0     TriN    Di23
# 229       dissolved                 1     TriN    Di24
# 230       dissolved                 1     TriN    Di25
# 231       dissolved                 1     TriN    Di26
# 232       dissolved                 1     TriN    Di27
# 233       dissolved                 1     TriN    Di28
# 234       dissolved                 1     TriN    Di29
# 235       dissolved                 1     TriN    Di30
# 236       dissolved                 1     TriN    Di31
# 237       dissolved                 1     TriN    Di32
# 238       dissolved                 1     TriN    Di33
# 239       dissolved                 1     TriN    Di34
# 240          turbid                 0     TriO    Di17
# 241          turbid                 0     TriO    Di18
# 242          turbid                 0     TriO    Di19
# 243       dissolved                 1     TriO    Di20
# 244          turbid                 0     TriO    Di21
# 245          turbid                 0     TriO    Di22
# 246          turbid                 0     TriO    Di23
# 247       dissolved                 1     TriO    Di24
# 248       dissolved                 1     TriO    Di25
# 249       dissolved                 1     TriO    Di26
# 250       dissolved                 1     TriO    Di27
# 251       dissolved                 1     TriO    Di28
# 252       dissolved                 1     TriO    Di29
# 253       dissolved                 1     TriO    Di30
# 254       dissolved                 1     TriO    Di31
# 255          turbid                 0     TriO    Di32
# 256       dissolved                 1     TriO    Di33
# 257       dissolved                 1     TriO    Di34
# 258          turbid                 0     TriP    Di17
# 259          turbid                 0     TriP    Di18
# 260          turbid                 0     TriP    Di19
# 261          turbid                 0     TriP    Di20
# 262          turbid                 0     TriP    Di21
# 263          turbid                 0     TriP    Di22
# 264          turbid                 0     TriP    Di23
# 265       dissolved                 1     TriP    Di24
# 266       dissolved                 1     TriP    Di25
# 267       dissolved                 1     TriP    Di26
# 268       dissolved                 1     TriP    Di27
# 269       dissolved                 1     TriP    Di28
# 270       dissolved                 1     TriP    Di29
# 271       dissolved                 1     TriP    Di30
# 272       dissolved                 1     TriP    Di31
# 273          turbid                 0     TriP    Di32
# 274       dissolved                 1     TriP    Di33
# 275       dissolved                 1     TriP    Di34
# 276          turbid                 0     TriQ    Di17
# 277       dissolved                 1     TriQ    Di18
# 278          turbid                 0     TriQ    Di19
# 279       dissolved                 1     TriQ    Di20
# 280          turbid                 0     TriQ    Di21
# 281          turbid                 0     TriQ    Di22
# 282          turbid                 0     TriQ    Di23
# 283       dissolved                 1     TriQ    Di24
# 284       dissolved                 1     TriQ    Di25
# 285       dissolved                 1     TriQ    Di26
# 286          turbid                 0     TriQ    Di27
# 287       dissolved                 1     TriQ    Di28
# 288       dissolved                 1     TriQ    Di29
# 289       dissolved                 1     TriQ    Di30
# 290       dissolved                 1     TriQ    Di31
# 291          turbid                 0     TriQ    Di32
# 292       dissolved                 1     TriQ    Di33
# 293          turbid                 0     TriQ    Di34
# 294       dissolved                 1     TriR    Di17
# 295       dissolved                 1     TriR    Di18
# 296          turbid                 0     TriR    Di19
# 297       dissolved                 1     TriR    Di20
# 298          turbid                 0     TriR    Di21
# 299       dissolved                 1     TriR    Di22
# 300       dissolved                 1     TriR    Di23
# 301       dissolved                 1     TriR    Di24
# 302       dissolved                 1     TriR    Di25
# 303       dissolved                 1     TriR    Di26
# 304       dissolved                 1     TriR    Di27
# 305       dissolved                 1     TriR    Di28
# 306       dissolved                 1     TriR    Di29
# 307       dissolved                 1     TriR    Di30
# 308       dissolved                 1     TriR    Di31
# 309       dissolved                 1     TriR    Di32
# 310       dissolved                 1     TriR    Di33
# 311       dissolved                 1     TriR    Di34
# 312       dissolved                 1     TriS    Di17
# 313       dissolved                 1     TriS    Di18
# ...
# 112               162.14                       3.0      51.2
# 113               162.14                       3.0      51.2
# 114                390.4                       6.0      51.2
# 115                390.4                       6.0      51.2
# 116                390.4                       6.0      51.2
# 117                390.4                       6.0      51.2
# 118                390.4                       6.0      51.2
# 119                390.4                       6.0      51.2
# 120                390.4                       6.0      51.2
# 121                390.4                       6.0      51.2
# 122                390.4                       6.0      51.2
# 123                390.4                       6.0      51.2
# 124                390.4                       6.0      51.2
# 125                390.4                       6.0      51.2
# 126                390.4                       6.0      51.2
# 127                390.4                       6.0      51.2
# 128                390.4                       6.0      51.2
# 129                390.4                       6.0      51.2
# 130                390.4                       6.0      51.2
# 131                390.4                       6.0      51.2
# 132               178.14                       3.0      71.4
# 133               178.14                       3.0      71.4
# 134               178.14                       3.0      71.4
# 135               178.14                       3.0      71.4
# 136               178.14                       3.0      71.4
# 137               178.14                       3.0      71.4
# 138               178.14                       3.0      71.4
# 139               178.14                       3.0      71.4
# 140               178.14                       3.0      71.4
# 141               178.14                       3.0      71.4
# 142               178.14                       3.0      71.4
# 143               178.14                       3.0      71.4
# 144               178.14                       3.0      71.4
# 145               178.14                       3.0      71.4
# 146               178.14                       3.0      71.4
# 147               178.14                       3.0      71.4
# 148               178.14                       3.0      71.4
# 149               178.14                       3.0      71.4
# 150                329.3                       6.0      54.4
# 151                329.3                       6.0      54.4
# 152                329.3                       6.0      54.4
# 153                329.3                       6.0      54.4
# 154                329.3                       6.0      54.4
# 155                329.3                       6.0      54.4
# 156                329.3                       6.0      54.4
# 157                329.3                       6.0      54.4
# 158                329.3                       6.0      54.4
# 159                329.3                       6.0      54.4
# 160                329.3                       6.0      54.4
# 161                329.3                       6.0      54.4
# 162                329.3                       6.0      54.4
# 163                329.3                       6.0      54.4
# 164                329.3                       6.0      54.4
# 165                329.3                       6.0      54.4
# 166                329.3                       6.0      54.4
# 167                329.3                       6.0      54.4
# 168                393.4                       6.0      89.9
# 169                393.4                       6.0      89.9
# 170                393.4                       6.0      89.9
# 171                393.4                       6.0      89.9
# 172                393.4                       6.0      89.9
# 173                393.4                       6.0      89.9
# 174                393.4                       6.0      89.9
# 175                393.4                       6.0      89.9
# 176                393.4                       6.0      89.9
# 177                393.4                       6.0      89.9
# 178                393.4                       6.0      89.9
# 179                393.4                       6.0      89.9
# 180                393.4                       6.0      89.9
# 181                393.4                       6.0      89.9
# 182                393.4                       6.0      89.9
# 183                393.4                       6.0      89.9
# 184                393.4                       6.0      89.9
# 185                393.4                       6.0      89.9
# 186                462.5                       9.0      51.2
# 187                462.5                       9.0      51.2
# 188                462.5                       9.0      51.2
# 189                462.5                       9.0      51.2
# 190                462.5                       9.0      51.2
# 191                462.5                       9.0      51.2
# 192                462.5                       9.0      51.2
# 193                462.5                       9.0      51.2
# 194                462.5                       9.0      51.2
# 195                462.5                       9.0      51.2
# 196                462.5                       9.0      51.2
# 197                462.5                       9.0      51.2
# 198                462.5                       9.0      51.2
# 199                462.5                       9.0      51.2
# 200                462.5                       9.0      51.2
# 201                462.5                       9.0      51.2
# 202                462.5                       9.0      51.2
# 203                462.5                       9.0      51.2
# 204                390.4                       6.0      51.2
# 205                390.4                       6.0      51.2
# 206                390.4                       6.0      51.2
# 207                390.4                       6.0      51.2
# 208                390.4                       6.0      51.2
# 209                390.4                       6.0      51.2
# 210                390.4                       6.0      51.2
# 211                390.4                       6.0      51.2
# 212                390.4                       6.0      51.2
# 213                390.4                       6.0      51.2
# 214                390.4                       6.0      51.2
# 215                390.4                       6.0      51.2
# 216                390.4                       6.0      51.2
# 217                390.4                       6.0      51.2
# 218                390.4                       6.0      51.2
# 219                390.4                       6.0      51.2
# 220                390.4                       6.0      51.2
# 221                390.4                       6.0      51.2
# 222                390.4                       6.0      51.2
# 223                390.4                       6.0      51.2
# 224                390.4                       6.0      51.2
# 225                390.4                       6.0      51.2
# 226                390.4                       6.0      51.2
# 227                390.4                       6.0      51.2
# 228                390.4                       6.0      51.2
# 229                390.4                       6.0      51.2
# 230                390.4                       6.0      51.2
# 231                390.4                       6.0      51.2
# 232                390.4                       6.0      51.2
# 233                390.4                       6.0      51.2
# 234                390.4                       6.0      51.2
# 235                390.4                       6.0      51.2
# 236                390.4                       6.0      51.2
# 237                390.4                       6.0      51.2
# 238                390.4                       6.0      51.2
# 239                390.4                       6.0      51.2
# 240                408.5                       6.0     136.0
# 241                408.5                       6.0     136.0
# 242                408.5                       6.0     136.0
# 243                408.5                       6.0     136.0
# 244                408.5                       6.0     136.0
# 245                408.5                       6.0     136.0
# 246                408.5                       6.0     136.0
# 247                408.5                       6.0     136.0
# 248                408.5                       6.0     136.0
# 249                408.5                       6.0     136.0
# 250                408.5                       6.0     136.0
# 251                408.5                       6.0     136.0
# 252                408.5                       6.0     136.0
# 253                408.5                       6.0     136.0
# 254                408.5                       6.0     136.0
# 255                408.5                       6.0     136.0
# 256                408.5                       6.0     136.0
# 257                408.5                       6.0     136.0
# 258                360.3                       6.0      90.6
# 259                360.3                       6.0      90.6
# 260                360.3                       6.0      90.6
# 261                360.3                       6.0      90.6
# 262                360.3                       6.0      90.6
# 263                360.3                       6.0      90.6
# 264                360.3                       6.0      90.6
# 265                360.3                       6.0      90.6
# 266                360.3                       6.0      90.6
# 267                360.3                       6.0      90.6
# 268                360.3                       6.0      90.6
# 269                360.3                       6.0      90.6
# 270                360.3                       6.0      90.6
# 271                360.3                       6.0      90.6
# 272                360.3                       6.0      90.6
# 273                360.3                       6.0      90.6
# 274                360.3                       6.0      90.6
# 275                360.3                       6.0      90.6
# 276                  NaN                       NaN       NaN
# 277                  NaN                       NaN       NaN
# 278                  NaN                       NaN       NaN
# 279                  NaN                       NaN       NaN
# 280                  NaN                       NaN       NaN
# 281                  NaN                       NaN       NaN
# 282                  NaN                       NaN       NaN
# 283                  NaN                       NaN       NaN
# 284                  NaN                       NaN       NaN
# 285                  NaN                       NaN       NaN
# 286                  NaN                       NaN       NaN
# 287                  NaN                       NaN       NaN
# 288                  NaN                       NaN       NaN
# 289                  NaN                       NaN       NaN
# 290                  NaN                       NaN       NaN
# 291                  NaN                       NaN       NaN
# 292                  NaN                       NaN       NaN
# 293                  NaN                       NaN       NaN
# 294                480.5                      12.0      78.9
# 295                480.5                      12.0      78.9
# 296                480.5                      12.0      78.9
# 297                480.5                      12.0      78.9
# 298                480.5                      12.0      78.9
# 299                480.5                      12.0      78.9
# 300                480.5                      12.0      78.9
# 301                480.5                      12.0      78.9
# 302                480.5                      12.0      78.9
# 303                480.5                      12.0      78.9
# 304                480.5                      12.0      78.9
# 305                480.5                      12.0      78.9
# 306                480.5                      12.0      78.9
# 307                480.5                      12.0      78.9
# 308                480.5                      12.0      78.9
# 309                480.5                      12.0      78.9
# 310                480.5                      12.0      78.9
# 311                480.5                      12.0      78.9
# 312               262.26                       5.0      51.2
# 313               262.26                       5.0      51.2
# 314               262.26                       5.0      51.2
# 315               262.26                       5.0      51.2
# 316               262.26                       5.0      51.2
# 317               262.26                       5.0      51.2
# 318               262.26                       5.0      51.2
# 319               262.26                       5.0      51.2
# 320               262.26                       5.0      51.2
# 321               262.26                       5.0      51.2
# 322               262.26                       5.0      51.2
# 323               262.26                       5.0      51.2
# 324               262.26                       5.0      51.2
# 325               262.26                       5.0      51.2
# 326               262.26                       5.0      51.2
# 327               262.26                       5.0      51.2
# 328               262.26                       5.0      51.2
# 329               262.26                       5.0      51.2
# 330               210.14                       3.0     112.0
# 331               210.14                       3.0     112.0
# 332               210.14                       3.0     112.0
# 333               210.14                       3.0     112.0
# 334               210.14                       3.0     112.0
# 335               210.14                       3.0     112.0
# 336               210.14                       3.0     112.0
# 337               210.14                       3.0     112.0
# 338               210.14                       3.0     112.0
# 339               210.14                       3.0     112.0
# 340               210.14                       3.0     112.0
# 341               210.14                       3.0     112.0
# 342               210.14                       3.0     112.0
# 343               210.14                       3.0     112.0
# 344               210.14                       3.0     112.0
# 345               210.14                       3.0     112.0
# 346               210.14                       3.0     112.0
# 347               210.14                       3.0     112.0
# 348                468.5                       9.0      51.2
# 349                468.5                       9.0      51.2
# 350                468.5                       9.0      51.2
# 351                468.5                       9.0      51.2
# 352                468.5                       9.0      51.2
# 353                468.5                       9.0      51.2
# 354                468.5                       9.0      51.2
# 355                468.5                       9.0      51.2
# 356                468.5                       9.0      51.2
# 357                468.5                       9.0      51.2
# 358                468.5                       9.0      51.2
# 359                468.5                       9.0      51.2
# 360                468.5                       9.0      51.2
# 361                468.5                       9.0      51.2
# 362                468.5                       9.0      51.2
# 363                468.5                       9.0      51.2
# 364                468.5                       9.0      51.2
# 365                468.5                       9.0      51.2

# %%
turbidity_final.shape
# Out:
# (366, 39)

# %%
turbidity_final.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')

# %%
duplicates = turbidity_final[turbidity_final.duplicated(subset=['di_smiles', 'tri_smiles'])]
duplicates
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, precursor_combination, plate_number, turbidity, turbidity_label, turbidity_binary, tri_name, di_name, di_smiles, tri_smiles, di_cactvs_fingerprint, di_charge, di_complexity, di_covalent_unit_count, di_defined_atom_stereo_count, di_defined_bond_stereo_count, di_exact_mass, di_h_bond_acceptor_count, di_h_bond_donor_count, di_heavy_atom_count, di_xlogp, di_molecular_weight, di_rotatable_bond_count, di_tpsa, tri_cactvs_fingerprint, tri_charge, tri_complexity, tri_covalent_unit_count, tri_defined_atom_stereo_count, tri_defined_bond_stereo_count, tri_exact_mass, tri_h_bond_acceptor_count, tri_h_bond_donor_count, tri_heavy_atom_count, tri_xlogp, tri_molecular_weight, tri_rotatable_bond_count, tri_tpsa]
# Index: []

# %% [markdown]
# ### Adding the number fo aromatic rings

# %%
info_arom = pd.read_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/data_supplmentary_hardness_arom_nbd.csv')

# %%
aromatic_ring_mapping = info_arom.set_index('precursor')['nbr_atomatic_ring'].to_dict()


turbidity_final['di_arom_group'] = turbidity_final['di_name'].str[2:].map(aromatic_ring_mapping)
turbidity_final['tri_arom_group'] = turbidity_final['tri_name'].str[3:].map(aromatic_ring_mapping)

turbidity_final.to_csv('/Users/davidsegura/git/Leveraging_LLMs_causality/cage_SAD_llm/data/new_1_turbidity_data.csv')
